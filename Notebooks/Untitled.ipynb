# %%
import os
path=os.getcwd()+"/../Build/Models/EmbryonClassif/embryon_classif/"
os.listdir(path)
# Out:
# ['rl22jbyy',
#  '3itldm3p',
#  'jgkvqrcl',
#  '3po79pw1',
#  'fmqdwuwm',
#  's6ru6ayc',
#  '1d6adh99',
#  '3ko4yjpq',
#  'rpc6u491',
#  '35nbkkgy',
#  '258tn9gn',
#  '1lk65uiw',
#  '3daysjyc',
#  '3ak8cxdv',
#  'm77noxm6',
#  '1puy5u0u',
#  '301j85zo',
#  '8oevse2l',
#  'kognt93q',
#  'mvbd9wga',
#  '2txwxygz',
#  '1mb9bl1r',
#  '1wp7dd3l',
#  '2qnkexan',
#  '3hqn4nkq',
#  '10sh2szk',
#  '1ai1fgyk',
#  '3f6b885t',
#  '2d2ga05z',
#  '3ofv3d18',
#  'bcmymcbc',
#  '1ptqrrfc',
#  'orsh4six',
#  '3pv79e0e',
#  '1404w36t']

# %%
import os
import shutil
import pandas as pd
files = []
source_dir = [path]
dest_dir = os.getcwd()+"/../csvfiles/"
df=pd.DataFrame()
for i in os.listdir(path):
    print(i)
    print(os.listdir(path+i))
    if os.path.isfile(path+i+"/results.csv"):
        df=pd.read_csv(path+i+"/results.csv")
        df.to_csv(dest_dir+i+".csv")
# Out:
# rl22jbyy
# ['checkpoints']
# 3itldm3p
# ['checkpoints']
# jgkvqrcl
# ['checkpoints']
# 3po79pw1
# ['checkpoints', 'results.csv']
# fmqdwuwm
# ['checkpoints', 'results.csv']
# s6ru6ayc
# ['checkpoints', 'results.csv']
# 1d6adh99
# ['checkpoints', 'results.csv']
# 3ko4yjpq
# ['checkpoints', 'results.csv']
# rpc6u491
# ['checkpoints']
# 35nbkkgy
# ['checkpoints', 'results.csv']
# 258tn9gn
# ['checkpoints', 'results.csv']
# 1lk65uiw
# ['checkpoints', 'results.csv']
# 3daysjyc
# ['checkpoints', 'results.csv']
# 3ak8cxdv
# ['checkpoints', 'results.csv']
# m77noxm6
# ['checkpoints', 'results.csv']
# 1puy5u0u
# ['checkpoints', 'results.csv']
# 301j85zo
# ['checkpoints', 'results.csv']
# 8oevse2l
# ['checkpoints', 'results.csv']
# kognt93q
# ['checkpoints', 'results.csv']
# mvbd9wga
# ['checkpoints', 'results.csv']
# 2txwxygz
# ['checkpoints', 'results.csv']
# 1mb9bl1r
# ['checkpoints', 'results.csv']
# 1wp7dd3l
# ['checkpoints', 'results.csv']
# 2qnkexan
# ['checkpoints', 'results.csv']
# ...
